# %% [markdown]
# # Notebook d'instalation

# %% [markdown]
# Dans ce notebook nous allons installer MMPose avec Cuda 12.4, avec Python en version 3.8 et en utilisant conda sous Linux.
# On commence par installer PyTorch :

# %%
import subprocess
subprocess.run(["conda", "init"])
subprocess.run(["conda","install","pytorch","torchvision","-c","pytorch"])
# Out:
# no change     /home/corentin/miniconda3/condabin/conda
# no change     /home/corentin/miniconda3/bin/conda
# no change     /home/corentin/miniconda3/bin/conda-env
# no change     /home/corentin/miniconda3/bin/activate
# no change     /home/corentin/miniconda3/bin/deactivate
# no change     /home/corentin/miniconda3/etc/profile.d/conda.sh
# no change     /home/corentin/miniconda3/etc/fish/conf.d/conda.fish
# no change     /home/corentin/miniconda3/shell/condabin/Conda.psm1
# no change     /home/corentin/miniconda3/shell/condabin/conda-hook.ps1
# no change     /home/corentin/miniconda3/lib/python3.13/site-packages/xontrib/conda.xsh
# no change     /home/corentin/miniconda3/etc/profile.d/conda.csh
# no change     /home/corentin/.bashrc
# No action taken.
# CondaToSNonInteractiveError: Terms of Service have not been accepted for the following channels. Please accept or remove them before proceeding:
#     - https://repo.anaconda.com/pkgs/main
#     - https://repo.anaconda.com/pkgs/r
#
# To accept these channels' Terms of Service, run the following commands:
#     conda tos accept --override-channels --channel https://repo.anaconda.com/pkgs/main
#     conda tos accept --override-channels --channel https://repo.anaconda.com/pkgs/r
#
# For information on safely removing channels from your conda configuration,
# please see the official documentation:
#
#     https://www.anaconda.com/docs/tools/working-with-conda/channels
# CompletedProcess(args=['conda', 'install', 'pytorch', 'torchvision', '-c', 'pytorch'], returncode=1)

# %% [markdown]
# Installation de openmim puis installation de mmengine et mmcv. On ne prend pas la dernière version de mmcv car elle pose problème.

# %%
# %pip install -U openmim
subprocess.run(["mim","install","mmengine"])
subprocess.run(["mim","install","mmcv>=2.0.0rc4,<2.2.0"])
# Out:
# Collecting openmim
#   Downloading openmim-0.3.9-py2.py3-none-any.whl.metadata (16 kB)
# Collecting Click (from openmim)
#   Downloading click-8.1.8-py3-none-any.whl.metadata (2.3 kB)
# Collecting colorama (from openmim)
#   Downloading colorama-0.4.6-py2.py3-none-any.whl.metadata (17 kB)
# Collecting model-index (from openmim)
#   Downloading model_index-0.1.11-py3-none-any.whl.metadata (3.9 kB)
# Collecting opendatalab (from openmim)
#   Downloading opendatalab-0.0.10-py3-none-any.whl.metadata (6.4 kB)
# Collecting pandas (from openmim)
#   Downloading pandas-2.0.3-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (18 kB)
# Requirement already satisfied: pip>=19.3 in ./.env/lib/python3.8/site-packages (from openmim) (25.0.1)
# Collecting requests (from openmim)
#   Downloading requests-2.32.4-py3-none-any.whl.metadata (4.9 kB)
# Collecting rich (from openmim)
#   Using cached rich-14.2.0-py3-none-any.whl.metadata (18 kB)
# Collecting tabulate (from openmim)
#   Downloading tabulate-0.9.0-py3-none-any.whl.metadata (34 kB)
# Collecting pyyaml (from model-index->openmim)
#   Downloading PyYAML-6.0.3-cp38-cp38-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (2.1 kB)
# Collecting markdown (from model-index->openmim)
#   Downloading Markdown-3.7-py3-none-any.whl.metadata (7.0 kB)
# Collecting ordered-set (from model-index->openmim)
#   Downloading ordered_set-4.1.0-py3-none-any.whl.metadata (5.3 kB)
# Collecting pycryptodome (from opendatalab->openmim)
#   Downloading pycryptodome-3.23.0-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.4 kB)
# Collecting tqdm (from opendatalab->openmim)
#   Using cached tqdm-4.67.1-py3-none-any.whl.metadata (57 kB)
# Collecting openxlab (from opendatalab->openmim)
#   Downloading openxlab-0.1.3-py3-none-any.whl.metadata (3.8 kB)
# Collecting charset_normalizer<4,>=2 (from requests->openmim)
#   Downloading charset_normalizer-3.4.4-cp38-cp38-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (37 kB)
# Collecting idna<4,>=2.5 (from requests->openmim)
#   Using cached idna-3.11-py3-none-any.whl.metadata (8.4 kB)
# Collecting urllib3<3,>=1.21.1 (from requests->openmim)
#   Downloading urllib3-2.2.3-py3-none-any.whl.metadata (6.5 kB)
# Collecting certifi>=2017.4.17 (from requests->openmim)
#   Using cached certifi-2025.11.12-py3-none-any.whl.metadata (2.5 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in ./.env/lib/python3.8/site-packages (from pandas->openmim) (2.9.0.post0)
# Collecting pytz>=2020.1 (from pandas->openmim)
#   Using cached pytz-2025.2-py2.py3-none-any.whl.metadata (22 kB)
# Collecting tzdata>=2022.1 (from pandas->openmim)
#   Downloading tzdata-2025.3-py2.py3-none-any.whl.metadata (1.4 kB)
# Collecting numpy>=1.20.3 (from pandas->openmim)
#   Downloading numpy-1.24.4-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.6 kB)
# Collecting markdown-it-py>=2.2.0 (from rich->openmim)
#   Downloading markdown_it_py-3.0.0-py3-none-any.whl.metadata (6.9 kB)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in ./.env/lib/python3.8/site-packages (from rich->openmim) (2.19.2)
# Collecting mdurl~=0.1 (from markdown-it-py>=2.2.0->rich->openmim)
#   Using cached mdurl-0.1.2-py3-none-any.whl.metadata (1.6 kB)
# Requirement already satisfied: six>=1.5 in ./.env/lib/python3.8/site-packages (from python-dateutil>=2.8.2->pandas->openmim) (1.17.0)
# Requirement already satisfied: importlib-metadata>=4.4 in ./.env/lib/python3.8/site-packages (from markdown->model-index->openmim) (8.5.0)
# Collecting filelock~=3.14.0 (from openxlab->opendatalab->openmim)
#   Downloading filelock-3.14.0-py3-none-any.whl.metadata (2.8 kB)
# Collecting oss2~=2.17.0 (from openxlab->opendatalab->openmim)
#   Downloading oss2-2.17.0.tar.gz (259 kB)
#   Preparing metadata (setup.py) ... done
# Collecting packaging~=24.0 (from openxlab->opendatalab->openmim)
#   Downloading packaging-24.2-py3-none-any.whl.metadata (3.2 kB)
# Collecting pytz>=2020.1 (from pandas->openmim)
#   Downloading pytz-2023.4-py2.py3-none-any.whl.metadata (22 kB)
# Collecting requests (from openmim)
#   Downloading requests-2.28.2-py3-none-any.whl.metadata (4.6 kB)
# Collecting rich (from openmim)
#   Downloading rich-13.4.2-py3-none-any.whl.metadata (18 kB)
# Collecting setuptools~=60.2.0 (from openxlab->opendatalab->openmim)
#   Downloading setuptools-60.2.0-py3-none-any.whl.metadata (5.1 kB)
# Collecting tqdm (from opendatalab->openmim)
#   Downloading tqdm-4.65.2-py3-none-any.whl.metadata (56 kB)
# Collecting urllib3<1.27,>=1.21.1 (from requests->openmim)
#   Downloading urllib3-1.26.20-py2.py3-none-any.whl.metadata (50 kB)
# Requirement already satisfied: typing-extensions<5.0,>=4.0.0 in ./.env/lib/python3.8/site-packages (from rich->openmim) (4.13.2)
# Requirement already satisfied: zipp>=3.20 in ./.env/lib/python3.8/site-packages (from importlib-metadata>=4.4->markdown->model-index->openmim) (3.20.2)
# Collecting crcmod>=1.7 (from oss2~=2.17.0->openxlab->opendatalab->openmim)
#   Downloading crcmod-1.7.tar.gz (89 kB)
#   Preparing metadata (setup.py) ... done
# Collecting aliyun-python-sdk-kms>=2.4.1 (from oss2~=2.17.0->openxlab->opendatalab->openmim)
#   Downloading aliyun_python_sdk_kms-2.16.5-py2.py3-none-any.whl.metadata (1.5 kB)
# Collecting aliyun-python-sdk-core>=2.13.12 (from oss2~=2.17.0->openxlab->opendatalab->openmim)
#   Downloading aliyun-python-sdk-core-2.16.0.tar.gz (449 kB)
#   Preparing metadata (setup.py) ... done
# Collecting jmespath<1.0.0,>=0.9.3 (from aliyun-python-sdk-core>=2.13.12->oss2~=2.17.0->openxlab->opendatalab->openmim)
#   Downloading jmespath-0.10.0-py2.py3-none-any.whl.metadata (8.0 kB)
# Collecting cryptography>=3.0.0 (from aliyun-python-sdk-core>=2.13.12->oss2~=2.17.0->openxlab->opendatalab->openmim)
#   Downloading cryptography-46.0.3-cp38-abi3-manylinux_2_34_x86_64.whl.metadata (5.7 kB)
# Collecting cffi>=1.14 (from cryptography>=3.0.0->aliyun-python-sdk-core>=2.13.12->oss2~=2.17.0->openxlab->opendatalab->openmim)
#   Downloading cffi-1.17.1-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting pycparser (from cffi>=1.14->cryptography>=3.0.0->aliyun-python-sdk-core>=2.13.12->oss2~=2.17.0->openxlab->opendatalab->openmim)
#   Using cached pycparser-2.23-py3-none-any.whl.metadata (993 bytes)
# Downloading openmim-0.3.9-py2.py3-none-any.whl (52 kB)
# Downloading click-8.1.8-py3-none-any.whl (98 kB)
# Downloading colorama-0.4.6-py2.py3-none-any.whl (25 kB)
# Downloading model_index-0.1.11-py3-none-any.whl (34 kB)
# Downloading opendatalab-0.0.10-py3-none-any.whl (29 kB)
# Downloading pandas-2.0.3-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (12.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.4/12.4 MB 2.3 MB/s eta 0:00:0000:0100:01
# Downloading tabulate-0.9.0-py3-none-any.whl (35 kB)
# Using cached certifi-2025.11.12-py3-none-any.whl (159 kB)
# Downloading charset_normalizer-3.4.4-cp38-cp38-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (147 kB)
# Using cached idna-3.11-py3-none-any.whl (71 kB)
# Downloading markdown_it_py-3.0.0-py3-none-any.whl (87 kB)
# Downloading numpy-1.24.4-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (17.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.3/17.3 MB 2.8 MB/s eta 0:00:0000:0100:01
# Downloading tzdata-2025.3-py2.py3-none-any.whl (348 kB)
# Downloading Markdown-3.7-py3-none-any.whl (106 kB)
# Downloading openxlab-0.1.3-py3-none-any.whl (314 kB)
# Downloading requests-2.28.2-py3-none-any.whl (62 kB)
# Downloading rich-13.4.2-py3-none-any.whl (239 kB)
# Downloading pytz-2023.4-py2.py3-none-any.whl (506 kB)
# Downloading PyYAML-6.0.3-cp38-cp38-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (806 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 806.0/806.0 kB 3.0 MB/s eta 0:00:00a 0:00:01
# Downloading tqdm-4.65.2-py3-none-any.whl (77 kB)
# Downloading urllib3-1.26.20-py2.py3-none-any.whl (144 kB)
# Downloading ordered_set-4.1.0-py3-none-any.whl (7.6 kB)
# Downloading pycryptodome-3.23.0-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 3.2 MB/s eta 0:00:00a 0:00:01
# Downloading filelock-3.14.0-py3-none-any.whl (12 kB)
# Using cached mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Downloading packaging-24.2-py3-none-any.whl (65 kB)
# Downloading setuptools-60.2.0-py3-none-any.whl (953 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 953.1/953.1 kB 2.7 MB/s eta 0:00:00a 0:00:01
# Downloading aliyun_python_sdk_kms-2.16.5-py2.py3-none-any.whl (99 kB)
# Downloading cryptography-46.0.3-cp38-abi3-manylinux_2_34_x86_64.whl (4.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 2.8 MB/s eta 0:00:00a 0:00:01
# Downloading jmespath-0.10.0-py2.py3-none-any.whl (24 kB)
# Downloading cffi-1.17.1-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (446 kB)
# Using cached pycparser-2.23-py3-none-any.whl (118 kB)
# Building wheels for collected packages: oss2, aliyun-python-sdk-core, crcmod
#   Building wheel for oss2 (setup.py) ... done
#   Created wheel for oss2: filename=oss2-2.17.0-py3-none-any.whl size=112370 sha256=13c2f171824ecf3fa17b5f0f96055ed53c14550b802cf5ef1c568eac13998ce8
#   Stored in directory: /home/corentin/.cache/pip/wheels/84/f1/a7/a20c3f53c7dbd8a1e5aa17ab1759465203b4ee46d6b3994dd2
#   Building wheel for aliyun-python-sdk-core (setup.py) ... done
#   Created wheel for aliyun-python-sdk-core: filename=aliyun_python_sdk_core-2.16.0-py3-none-any.whl size=535315 sha256=1cdc5cd4e52b2b8e7090bb76943e882d1eaaa8498a5f1675a7bbdc683d8b9055
#   Stored in directory: /home/corentin/.cache/pip/wheels/b2/49/69/4ff7cddf922bb14b3cd172290d83582ec72051d43333e70b69
#   Building wheel for crcmod (setup.py) ... done
#   Created wheel for crcmod: filename=crcmod-1.7-cp38-cp38-linux_x86_64.whl size=30442 sha256=96b3615facbbef6b392c332502e679cc839d86f4523c8cebf030f6a992de3520
#   Stored in directory: /home/corentin/.cache/pip/wheels/ca/5a/02/f3acf982a026f3319fb3e798a8dca2d48fafee7761788562e9
# Successfully built oss2 aliyun-python-sdk-core crcmod
# Installing collected packages: pytz, crcmod, urllib3, tzdata, tqdm, tabulate, setuptools, pyyaml, pycryptodome, pycparser, packaging, ordered-set, numpy, mdurl, jmespath, idna, filelock, colorama, Click, charset_normalizer, certifi, requests, pandas, markdown-it-py, markdown, cffi, rich, model-index, cryptography, aliyun-python-sdk-core, aliyun-python-sdk-kms, oss2, openxlab, opendatalab, openmim
#   Attempting uninstall: setuptools
#     Found existing installation: setuptools 75.3.2
#     Uninstalling setuptools-75.3.2:
#       Successfully uninstalled setuptools-75.3.2
#   Attempting uninstall: packaging
#     Found existing installation: packaging 25.0
#     Uninstalling packaging-25.0:
#       Successfully uninstalled packaging-25.0
# Successfully installed Click-8.1.8 aliyun-python-sdk-core-2.16.0 aliyun-python-sdk-kms-2.16.5 certifi-2025.11.12 cffi-1.17.1 charset_normalizer-3.4.4 colorama-0.4.6 crcmod-1.7 cryptography-46.0.3 filelock-3.14.0 idna-3.11 jmespath-0.10.0 markdown-3.7 markdown-it-py-3.0.0 mdurl-0.1.2 model-index-0.1.11 numpy-1.24.4 opendatalab-0.0.10 openmim-0.3.9 openxlab-0.1.3 ordered-set-4.1.0 oss2-2.17.0 packaging-24.2 pandas-2.0.3 pycparser-2.23 pycryptodome-3.23.0 pytz-2023.4 pyyaml-6.0.3 requests-2.28.2 rich-13.4.2 setuptools-60.2.0 tabulate-0.9.0 tqdm-4.65.2 tzdata-2025.3 urllib3-1.26.20
# Note: you may need to restart the kernel to use updated packages.
# Traceback (most recent call last):
#   File "/home/corentin/Documents/Cours/L3/Projet Midl 2/ProjetMIDL2/.env/bin/mim", line 10, in <module>
#     sys.exit(cli())
#   File "/home/corentin/Documents/Cours/L3/Projet Midl 2/ProjetMIDL2/.env/lib/python3.8/site-packages/click/core.py", line 1161, in __call__
#     return self.main(*args, **kwargs)
#   File "/home/corentin/Documents/Cours/L3/Projet Midl 2/ProjetMIDL2/.env/lib/python3.8/site-packages/click/core.py", line 1082, in main
#     rv = self.invoke(ctx)
#   File "/home/corentin/Documents/Cours/L3/Projet Midl 2/ProjetMIDL2/.env/lib/python3.8/site-packages/click/core.py", line 1697, in invoke
#     return _process_result(sub_ctx.command.invoke(sub_ctx))
#   File "/home/corentin/Documents/Cours/L3/Projet Midl 2/ProjetMIDL2/.env/lib/python3.8/site-packages/click/core.py", line 1443, in invoke
#     return ctx.invoke(self.callback, **ctx.params)
#   File "/home/corentin/Documents/Cours/L3/Projet Midl 2/ProjetMIDL2/.env/lib/python3.8/site-packages/click/core.py", line 788, in invoke
#     return __callback(*args, **kwargs)
#   File "/home/corentin/Documents/Cours/L3/Projet Midl 2/ProjetMIDL2/.env/lib/python3.8/site-packages/mim/commands/install.py", line 72, in cli
#     exit_code = install(list(args), index_url=index_url, is_yes=is_yes)
#   File "/home/corentin/Documents/Cours/L3/Projet Midl 2/ProjetMIDL2/.env/lib/python3.8/site-packages/mim/commands/install.py", line 128, in install
#     install_args += ['-f', get_mmcv_full_find_link(mmcv_base_url)]
#   File "/home/corentin/Documents/Cours/L3/Projet Midl 2/ProjetMIDL2/.env/lib/python3.8/site-packages/mim/commands/install.py", line 165, in get_mmcv_full_find_link
#     torch_v, cuda_v = get_torch_cuda_version()
#   File "/home/corentin/Documents/Cours/L3/Projet Midl 2/ProjetMIDL2/.env/lib/python3.8/site-packages/mim/utils/utils.py", line 340, in get_torch_cuda_version
#     raise err
#   File "/home/corentin/Documents/Cours/L3/Projet Midl 2/ProjetMIDL2/.env/lib/python3.8/site-packages/mim/utils/utils.py", line 338, in get_torch_cuda_version
#     import torch
# ModuleNotFoundError: No module named 'torch'
# Traceback (most recent call last):
#   File "/home/corentin/Documents/Cours/L3/Projet Midl 2/ProjetMIDL2/.env/bin/mim", line 10, in <module>
#     sys.exit(cli())
#   File "/home/corentin/Documents/Cours/L3/Projet Midl 2/ProjetMIDL2/.env/lib/python3.8/site-packages/click/core.py", line 1161, in __call__
#     return self.main(*args, **kwargs)
#   File "/home/corentin/Documents/Cours/L3/Projet Midl 2/ProjetMIDL2/.env/lib/python3.8/site-packages/click/core.py", line 1082, in main
#     rv = self.invoke(ctx)
#   File "/home/corentin/Documents/Cours/L3/Projet Midl 2/ProjetMIDL2/.env/lib/python3.8/site-packages/click/core.py", line 1697, in invoke
#     return _process_result(sub_ctx.command.invoke(sub_ctx))
#   File "/home/corentin/Documents/Cours/L3/Projet Midl 2/ProjetMIDL2/.env/lib/python3.8/site-packages/click/core.py", line 1443, in invoke
#     return ctx.invoke(self.callback, **ctx.params)
#   File "/home/corentin/Documents/Cours/L3/Projet Midl 2/ProjetMIDL2/.env/lib/python3.8/site-packages/click/core.py", line 788, in invoke
#     return __callback(*args, **kwargs)
#   File "/home/corentin/Documents/Cours/L3/Projet Midl 2/ProjetMIDL2/.env/lib/python3.8/site-packages/mim/commands/install.py", line 72, in cli
#     exit_code = install(list(args), index_url=index_url, is_yes=is_yes)
#   File "/home/corentin/Documents/Cours/L3/Projet Midl 2/ProjetMIDL2/.env/lib/python3.8/site-packages/mim/commands/install.py", line 128, in install
#     install_args += ['-f', get_mmcv_full_find_link(mmcv_base_url)]
#   File "/home/corentin/Documents/Cours/L3/Projet Midl 2/ProjetMIDL2/.env/lib/python3.8/site-packages/mim/commands/install.py", line 165, in get_mmcv_full_find_link
#     torch_v, cuda_v = get_torch_cuda_version()
#   File "/home/corentin/Documents/Cours/L3/Projet Midl 2/ProjetMIDL2/.env/lib/python3.8/site-packages/mim/utils/utils.py", line 340, in get_torch_cuda_version
#     raise err
#   File "/home/corentin/Documents/Cours/L3/Projet Midl 2/ProjetMIDL2/.env/lib/python3.8/site-packages/mim/utils/utils.py", line 338, in get_torch_cuda_version
#     import torch
# ModuleNotFoundError: No module named 'torch'
# CompletedProcess(args=['mim', 'install', 'mmcv>=2.0.0rc4,<2.2.0'], returncode=1)

# %% [markdown]
# Installation et build de MMPose a partir du dépot git

# %%
# !git clone https://github.com/open-mmlab/mmpose.git
# !cd mmpose
# %pip install -r mmpose/requirements.txt
# %pip install -v -e ./mmpose
# Out:
# fatal : le chemin de destination 'mmpose' existe déjà et n'est pas un répertoire vide.
# Requirement already satisfied: numpy in ./.env/lib/python3.8/site-packages (from -r /home/corentin/Documents/Cours/L3/Projet Midl 2/ProjetMIDL2/mmpose/requirements/build.txt (line 2)) (1.24.4)
# Collecting torch>=1.8 (from -r /home/corentin/Documents/Cours/L3/Projet Midl 2/ProjetMIDL2/mmpose/requirements/build.txt (line 3))
#   Downloading torch-2.4.1-cp38-cp38-manylinux1_x86_64.whl.metadata (26 kB)
# Collecting chumpy (from -r /home/corentin/Documents/Cours/L3/Projet Midl 2/ProjetMIDL2/mmpose/requirements/runtime.txt (line 1))
#   Downloading chumpy-0.70.tar.gz (50 kB)
#   Preparing metadata (setup.py) ... done
# Collecting json_tricks (from -r /home/corentin/Documents/Cours/L3/Projet Midl 2/ProjetMIDL2/mmpose/requirements/runtime.txt (line 2))
#   Downloading json_tricks-3.17.3-py2.py3-none-any.whl.metadata (16 kB)
# Collecting matplotlib (from -r /home/corentin/Documents/Cours/L3/Projet Midl 2/ProjetMIDL2/mmpose/requirements/runtime.txt (line 3))
#   Downloading matplotlib-3.7.5-cp38-cp38-manylinux_2_12_x86_64.manylinux2010_x86_64.whl.metadata (5.7 kB)
# Collecting munkres (from -r /home/corentin/Documents/Cours/L3/Projet Midl 2/ProjetMIDL2/mmpose/requirements/runtime.txt (line 4))
#   Downloading munkres-1.1.4-py2.py3-none-any.whl.metadata (980 bytes)
# Collecting opencv-python (from -r /home/corentin/Documents/Cours/L3/Projet Midl 2/ProjetMIDL2/mmpose/requirements/runtime.txt (line 6))
#   Using cached opencv_python-4.12.0.88-cp37-abi3-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (19 kB)
# Collecting pillow (from -r /home/corentin/Documents/Cours/L3/Projet Midl 2/ProjetMIDL2/mmpose/requirements/runtime.txt (line 7))
#   Downloading pillow-10.4.0-cp38-cp38-manylinux_2_28_x86_64.whl.metadata (9.2 kB)
# Collecting scipy (from -r /home/corentin/Documents/Cours/L3/Projet Midl 2/ProjetMIDL2/mmpose/requirements/runtime.txt (line 8))
#   Downloading scipy-1.10.1-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (58 kB)
# Collecting torchvision (from -r /home/corentin/Documents/Cours/L3/Projet Midl 2/ProjetMIDL2/mmpose/requirements/runtime.txt (line 9))
#   Downloading torchvision-0.19.1-cp38-cp38-manylinux1_x86_64.whl.metadata (6.0 kB)
# Collecting xtcocotools>=1.12 (from -r /home/corentin/Documents/Cours/L3/Projet Midl 2/ProjetMIDL2/mmpose/requirements/runtime.txt (line 10))
#   Downloading xtcocotools-1.14.3-cp38-cp38-manylinux1_x86_64.whl.metadata (364 bytes)
# Collecting coverage (from -r /home/corentin/Documents/Cours/L3/Projet Midl 2/ProjetMIDL2/mmpose/requirements/tests.txt (line 1))
#   Downloading coverage-7.6.1-cp38-cp38-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (8.3 kB)
# Collecting flake8 (from -r /home/corentin/Documents/Cours/L3/Projet Midl 2/ProjetMIDL2/mmpose/requirements/tests.txt (line 2))
#   Downloading flake8-7.1.2-py2.py3-none-any.whl.metadata (3.8 kB)
# Collecting interrogate (from -r /home/corentin/Documents/Cours/L3/Projet Midl 2/ProjetMIDL2/mmpose/requirements/tests.txt (line 3))
#   Downloading interrogate-1.7.0-py3-none-any.whl.metadata (37 kB)
# Collecting isort==4.3.21 (from -r /home/corentin/Documents/Cours/L3/Projet Midl 2/ProjetMIDL2/mmpose/requirements/tests.txt (line 4))
#   Downloading isort-4.3.21-py2.py3-none-any.whl.metadata (19 kB)
# Collecting parameterized (from -r /home/corentin/Documents/Cours/L3/Projet Midl 2/ProjetMIDL2/mmpose/requirements/tests.txt (line 5))
#   Downloading parameterized-0.9.0-py2.py3-none-any.whl.metadata (18 kB)
# Collecting pytest (from -r /home/corentin/Documents/Cours/L3/Projet Midl 2/ProjetMIDL2/mmpose/requirements/tests.txt (line 6))
#   Downloading pytest-8.3.5-py3-none-any.whl.metadata (7.6 kB)
# Collecting pytest-runner (from -r /home/corentin/Documents/Cours/L3/Projet Midl 2/ProjetMIDL2/mmpose/requirements/tests.txt (line 7))
#   Downloading pytest_runner-6.0.1-py3-none-any.whl.metadata (7.3 kB)
# Collecting xdoctest>=0.10.0 (from -r /home/corentin/Documents/Cours/L3/Projet Midl 2/ProjetMIDL2/mmpose/requirements/tests.txt (line 8))
#   Downloading xdoctest-1.3.0-py3-none-any.whl.metadata (35 kB)
# Collecting yapf (from -r /home/corentin/Documents/Cours/L3/Projet Midl 2/ProjetMIDL2/mmpose/requirements/tests.txt (line 9))
#   Using cached yapf-0.43.0-py3-none-any.whl.metadata (46 kB)
# Requirement already satisfied: requests in ./.env/lib/python3.8/site-packages (from -r /home/corentin/Documents/Cours/L3/Projet Midl 2/ProjetMIDL2/mmpose/requirements/optional.txt (line 1)) (2.28.2)
# Requirement already satisfied: filelock in ./.env/lib/python3.8/site-packages (from torch>=1.8->-r /home/corentin/Documents/Cours/L3/Projet Midl 2/ProjetMIDL2/mmpose/requirements/build.txt (line 3)) (3.14.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in ./.env/lib/python3.8/site-packages (from torch>=1.8->-r /home/corentin/Documents/Cours/L3/Projet Midl 2/ProjetMIDL2/mmpose/requirements/build.txt (line 3)) (4.13.2)
# Collecting sympy (from torch>=1.8->-r /home/corentin/Documents/Cours/L3/Projet Midl 2/ProjetMIDL2/mmpose/requirements/build.txt (line 3))
#   Downloading sympy-1.13.3-py3-none-any.whl.metadata (12 kB)
# Collecting networkx (from torch>=1.8->-r /home/corentin/Documents/Cours/L3/Projet Midl 2/ProjetMIDL2/mmpose/requirements/build.txt (line 3))
#   Downloading networkx-3.1-py3-none-any.whl.metadata (5.3 kB)
# Collecting jinja2 (from torch>=1.8->-r /home/corentin/Documents/Cours/L3/Projet Midl 2/ProjetMIDL2/mmpose/requirements/build.txt (line 3))
#   Using cached jinja2-3.1.6-py3-none-any.whl.metadata (2.9 kB)
# Collecting fsspec (from torch>=1.8->-r /home/corentin/Documents/Cours/L3/Projet Midl 2/ProjetMIDL2/mmpose/requirements/build.txt (line 3))
#   Downloading fsspec-2025.3.0-py3-none-any.whl.metadata (11 kB)
# Collecting nvidia-cuda-nvrtc-cu12==12.1.105 (from torch>=1.8->-r /home/corentin/Documents/Cours/L3/Projet Midl 2/ProjetMIDL2/mmpose/requirements/build.txt (line 3))
#   Downloading nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.1.105 (from torch>=1.8->-r /home/corentin/Documents/Cours/L3/Projet Midl 2/ProjetMIDL2/mmpose/requirements/build.txt (line 3))
#   Downloading nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.1.105 (from torch>=1.8->-r /home/corentin/Documents/Cours/L3/Projet Midl 2/ProjetMIDL2/mmpose/requirements/build.txt (line 3))
#   Downloading nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch>=1.8->-r /home/corentin/Documents/Cours/L3/Projet Midl 2/ProjetMIDL2/mmpose/requirements/build.txt (line 3))
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.1.3.1 (from torch>=1.8->-r /home/corentin/Documents/Cours/L3/Projet Midl 2/ProjetMIDL2/mmpose/requirements/build.txt (line 3))
#   Downloading nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.0.2.54 (from torch>=1.8->-r /home/corentin/Documents/Cours/L3/Projet Midl 2/ProjetMIDL2/mmpose/requirements/build.txt (line 3))
#   Downloading nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.2.106 (from torch>=1.8->-r /home/corentin/Documents/Cours/L3/Projet Midl 2/ProjetMIDL2/mmpose/requirements/build.txt (line 3))
#   Downloading nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.4.5.107 (from torch>=1.8->-r /home/corentin/Documents/Cours/L3/Projet Midl 2/ProjetMIDL2/mmpose/requirements/build.txt (line 3))
#   Downloading nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.1.0.106 (from torch>=1.8->-r /home/corentin/Documents/Cours/L3/Projet Midl 2/ProjetMIDL2/mmpose/requirements/build.txt (line 3))
#   Downloading nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-nccl-cu12==2.20.5 (from torch>=1.8->-r /home/corentin/Documents/Cours/L3/Projet Midl 2/ProjetMIDL2/mmpose/requirements/build.txt (line 3))
#   Downloading nvidia_nccl_cu12-2.20.5-py3-none-manylinux2014_x86_64.whl.metadata (1.8 kB)
# Collecting nvidia-nvtx-cu12==12.1.105 (from torch>=1.8->-r /home/corentin/Documents/Cours/L3/Projet Midl 2/ProjetMIDL2/mmpose/requirements/build.txt (line 3))
#   Downloading nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.7 kB)
# Collecting triton==3.0.0 (from torch>=1.8->-r /home/corentin/Documents/Cours/L3/Projet Midl 2/ProjetMIDL2/mmpose/requirements/build.txt (line 3))
#   Downloading triton-3.0.0-1-cp38-cp38-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.3 kB)
# Collecting nvidia-nvjitlink-cu12 (from nvidia-cusolver-cu12==11.4.5.107->torch>=1.8->-r /home/corentin/Documents/Cours/L3/Projet Midl 2/ProjetMIDL2/mmpose/requirements/build.txt (line 3))
#   Using cached nvidia_nvjitlink_cu12-12.9.86-py3-none-manylinux2010_x86_64.manylinux_2_12_x86_64.whl.metadata (1.7 kB)
# Requirement already satisfied: six>=1.11.0 in ./.env/lib/python3.8/site-packages (from chumpy->-r /home/corentin/Documents/Cours/L3/Projet Midl 2/ProjetMIDL2/mmpose/requirements/runtime.txt (line 1)) (1.17.0)
# Collecting contourpy>=1.0.1 (from matplotlib->-r /home/corentin/Documents/Cours/L3/Projet Midl 2/ProjetMIDL2/mmpose/requirements/runtime.txt (line 3))
#   Downloading contourpy-1.1.1-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.9 kB)
# Collecting cycler>=0.10 (from matplotlib->-r /home/corentin/Documents/Cours/L3/Projet Midl 2/ProjetMIDL2/mmpose/requirements/runtime.txt (line 3))
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib->-r /home/corentin/Documents/Cours/L3/Projet Midl 2/ProjetMIDL2/mmpose/requirements/runtime.txt (line 3))
#   Downloading fonttools-4.57.0-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (102 kB)
# Collecting kiwisolver>=1.0.1 (from matplotlib->-r /home/corentin/Documents/Cours/L3/Projet Midl 2/ProjetMIDL2/mmpose/requirements/runtime.txt (line 3))
#   Downloading kiwisolver-1.4.7-cp38-cp38-manylinux_2_5_x86_64.manylinux1_x86_64.whl.metadata (6.3 kB)
# Requirement already satisfied: packaging>=20.0 in ./.env/lib/python3.8/site-packages (from matplotlib->-r /home/corentin/Documents/Cours/L3/Projet Midl 2/ProjetMIDL2/mmpose/requirements/runtime.txt (line 3)) (24.2)
# Collecting pyparsing>=2.3.1 (from matplotlib->-r /home/corentin/Documents/Cours/L3/Projet Midl 2/ProjetMIDL2/mmpose/requirements/runtime.txt (line 3))
#   Downloading pyparsing-3.1.4-py3-none-any.whl.metadata (5.1 kB)
# Requirement already satisfied: python-dateutil>=2.7 in ./.env/lib/python3.8/site-packages (from matplotlib->-r /home/corentin/Documents/Cours/L3/Projet Midl 2/ProjetMIDL2/mmpose/requirements/runtime.txt (line 3)) (2.9.0.post0)
# Collecting importlib-resources>=3.2.0 (from matplotlib->-r /home/corentin/Documents/Cours/L3/Projet Midl 2/ProjetMIDL2/mmpose/requirements/runtime.txt (line 3))
#   Downloading importlib_resources-6.4.5-py3-none-any.whl.metadata (4.0 kB)
# Requirement already satisfied: setuptools>=18.0 in ./.env/lib/python3.8/site-packages (from xtcocotools>=1.12->-r /home/corentin/Documents/Cours/L3/Projet Midl 2/ProjetMIDL2/mmpose/requirements/runtime.txt (line 10)) (60.2.0)
# Collecting cython>=0.27.3 (from xtcocotools>=1.12->-r /home/corentin/Documents/Cours/L3/Projet Midl 2/ProjetMIDL2/mmpose/requirements/runtime.txt (line 10))
#   Downloading cython-3.2.3-cp38-cp38-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (4.3 kB)
# Collecting mccabe<0.8.0,>=0.7.0 (from flake8->-r /home/corentin/Documents/Cours/L3/Projet Midl 2/ProjetMIDL2/mmpose/requirements/tests.txt (line 2))
#   Downloading mccabe-0.7.0-py2.py3-none-any.whl.metadata (5.0 kB)
# Collecting pycodestyle<2.13.0,>=2.12.0 (from flake8->-r /home/corentin/Documents/Cours/L3/Projet Midl 2/ProjetMIDL2/mmpose/requirements/tests.txt (line 2))
#   Downloading pycodestyle-2.12.1-py2.py3-none-any.whl.metadata (4.5 kB)
# Collecting pyflakes<3.3.0,>=3.2.0 (from flake8->-r /home/corentin/Documents/Cours/L3/Projet Midl 2/ProjetMIDL2/mmpose/requirements/tests.txt (line 2))
#   Downloading pyflakes-3.2.0-py2.py3-none-any.whl.metadata (3.5 kB)
# Collecting attrs (from interrogate->-r /home/corentin/Documents/Cours/L3/Projet Midl 2/ProjetMIDL2/mmpose/requirements/tests.txt (line 3))
#   Downloading attrs-25.3.0-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: click>=7.1 in ./.env/lib/python3.8/site-packages (from interrogate->-r /home/corentin/Documents/Cours/L3/Projet Midl 2/ProjetMIDL2/mmpose/requirements/tests.txt (line 3)) (8.1.8)
# Requirement already satisfied: colorama in ./.env/lib/python3.8/site-packages (from interrogate->-r /home/corentin/Documents/Cours/L3/Projet Midl 2/ProjetMIDL2/mmpose/requirements/tests.txt (line 3)) (0.4.6)
# Collecting py (from interrogate->-r /home/corentin/Documents/Cours/L3/Projet Midl 2/ProjetMIDL2/mmpose/requirements/tests.txt (line 3))
#   Downloading py-1.11.0-py2.py3-none-any.whl.metadata (2.8 kB)
# Requirement already satisfied: tabulate in ./.env/lib/python3.8/site-packages (from interrogate->-r /home/corentin/Documents/Cours/L3/Projet Midl 2/ProjetMIDL2/mmpose/requirements/tests.txt (line 3)) (0.9.0)
# Collecting tomli (from interrogate->-r /home/corentin/Documents/Cours/L3/Projet Midl 2/ProjetMIDL2/mmpose/requirements/tests.txt (line 3))
#   Downloading tomli-2.3.0-py3-none-any.whl.metadata (10 kB)
# Collecting exceptiongroup>=1.0.0rc8 (from pytest->-r /home/corentin/Documents/Cours/L3/Projet Midl 2/ProjetMIDL2/mmpose/requirements/tests.txt (line 6))
#   Downloading exceptiongroup-1.3.1-py3-none-any.whl.metadata (6.7 kB)
# Collecting iniconfig (from pytest->-r /home/corentin/Documents/Cours/L3/Projet Midl 2/ProjetMIDL2/mmpose/requirements/tests.txt (line 6))
#   Downloading iniconfig-2.1.0-py3-none-any.whl.metadata (2.7 kB)
# Collecting pluggy<2,>=1.5 (from pytest->-r /home/corentin/Documents/Cours/L3/Projet Midl 2/ProjetMIDL2/mmpose/requirements/tests.txt (line 6))
#   Downloading pluggy-1.5.0-py3-none-any.whl.metadata (4.8 kB)
# Requirement already satisfied: platformdirs>=3.5.1 in ./.env/lib/python3.8/site-packages (from yapf->-r /home/corentin/Documents/Cours/L3/Projet Midl 2/ProjetMIDL2/mmpose/requirements/tests.txt (line 9)) (4.3.6)
# Requirement already satisfied: charset-normalizer<4,>=2 in ./.env/lib/python3.8/site-packages (from requests->-r /home/corentin/Documents/Cours/L3/Projet Midl 2/ProjetMIDL2/mmpose/requirements/optional.txt (line 1)) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in ./.env/lib/python3.8/site-packages (from requests->-r /home/corentin/Documents/Cours/L3/Projet Midl 2/ProjetMIDL2/mmpose/requirements/optional.txt (line 1)) (3.11)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in ./.env/lib/python3.8/site-packages (from requests->-r /home/corentin/Documents/Cours/L3/Projet Midl 2/ProjetMIDL2/mmpose/requirements/optional.txt (line 1)) (1.26.20)
# Requirement already satisfied: certifi>=2017.4.17 in ./.env/lib/python3.8/site-packages (from requests->-r /home/corentin/Documents/Cours/L3/Projet Midl 2/ProjetMIDL2/mmpose/requirements/optional.txt (line 1)) (2025.11.12)
# Requirement already satisfied: zipp>=3.1.0 in ./.env/lib/python3.8/site-packages (from importlib-resources>=3.2.0->matplotlib->-r /home/corentin/Documents/Cours/L3/Projet Midl 2/ProjetMIDL2/mmpose/requirements/runtime.txt (line 3)) (3.20.2)
# Collecting MarkupSafe>=2.0 (from jinja2->torch>=1.8->-r /home/corentin/Documents/Cours/L3/Projet Midl 2/ProjetMIDL2/mmpose/requirements/build.txt (line 3))
#   Downloading MarkupSafe-2.1.5-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.0 kB)
# Collecting mpmath<1.4,>=1.1.0 (from sympy->torch>=1.8->-r /home/corentin/Documents/Cours/L3/Projet Midl 2/ProjetMIDL2/mmpose/requirements/build.txt (line 3))
#   Downloading mpmath-1.3.0-py3-none-any.whl.metadata (8.6 kB)
# Downloading isort-4.3.21-py2.py3-none-any.whl (42 kB)
# Downloading torch-2.4.1-cp38-cp38-manylinux1_x86_64.whl (797.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 797.1/797.1 MB 2.2 MB/s eta 0:00:0000:0100:09
# Downloading nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 410.6/410.6 MB 2.3 MB/s eta 0:00:0000:0100:05
# Downloading nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.1/14.1 MB 2.3 MB/s eta 0:00:00a 0:00:01
# Downloading nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 2.5 MB/s eta 0:00:00a 0:00:01
# Downloading nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 823.6/823.6 kB 3.5 MB/s eta 0:00:00a 0:00:01
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 3.2 MB/s eta 0:00:0000:0100:06
# Downloading nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.6/121.6 MB 3.0 MB/s eta 0:00:0000:0100:02
# Downloading nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.5/56.5 MB 3.3 MB/s eta 0:00:0000:0100:01
# Downloading nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.2/124.2 MB 2.1 MB/s eta 0:00:0000:0100:02
# Downloading nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 196.0/196.0 MB 2.6 MB/s eta 0:00:0000:0100:02
# Downloading nvidia_nccl_cu12-2.20.5-py3-none-manylinux2014_x86_64.whl (176.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 176.2/176.2 MB 2.6 MB/s eta 0:00:0000:0100:02
# Downloading nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (99 kB)
# Downloading triton-3.0.0-1-cp38-cp38-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (209.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 209.4/209.4 MB 2.6 MB/s eta 0:00:0000:0100:03
# Downloading json_tricks-3.17.3-py2.py3-none-any.whl (27 kB)
# Downloading matplotlib-3.7.5-cp38-cp38-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (9.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.2/9.2 MB 2.7 MB/s eta 0:00:00a 0:00:01
# Downloading munkres-1.1.4-py2.py3-none-any.whl (7.0 kB)
# Using cached opencv_python-4.12.0.88-cp37-abi3-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (67.0 MB)
# Downloading pillow-10.4.0-cp38-cp38-manylinux_2_28_x86_64.whl (4.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 3.0 MB/s eta 0:00:00a 0:00:01
# Downloading scipy-1.10.1-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (34.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 34.5/34.5 MB 2.8 MB/s eta 0:00:0000:0100:01
# Downloading torchvision-0.19.1-cp38-cp38-manylinux1_x86_64.whl (7.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.0/7.0 MB 2.7 MB/s eta 0:00:00a 0:00:01
# Downloading xtcocotools-1.14.3-cp38-cp38-manylinux1_x86_64.whl (447 kB)
# Downloading coverage-7.6.1-cp38-cp38-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (235 kB)
# Downloading flake8-7.1.2-py2.py3-none-any.whl (57 kB)
# Downloading interrogate-1.7.0-py3-none-any.whl (46 kB)
# Downloading parameterized-0.9.0-py2.py3-none-any.whl (20 kB)
# Downloading pytest-8.3.5-py3-none-any.whl (343 kB)
# Downloading pytest_runner-6.0.1-py3-none-any.whl (7.2 kB)
# Downloading xdoctest-1.3.0-py3-none-any.whl (152 kB)
# Using cached yapf-0.43.0-py3-none-any.whl (256 kB)
# Downloading contourpy-1.1.1-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (301 kB)
# Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Downloading cython-3.2.3-cp38-cp38-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (3.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.5/3.5 MB 3.0 MB/s eta 0:00:00a 0:00:01
# Downloading exceptiongroup-1.3.1-py3-none-any.whl (16 kB)
# Downloading fonttools-4.57.0-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.7/4.7 MB 2.5 MB/s eta 0:00:00a 0:00:01
# Downloading importlib_resources-6.4.5-py3-none-any.whl (36 kB)
# Downloading kiwisolver-1.4.7-cp38-cp38-manylinux_2_5_x86_64.manylinux1_x86_64.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 3.4 MB/s eta 0:00:00a 0:00:01
# Downloading mccabe-0.7.0-py2.py3-none-any.whl (7.3 kB)
# Downloading pluggy-1.5.0-py3-none-any.whl (20 kB)
# Downloading pycodestyle-2.12.1-py2.py3-none-any.whl (31 kB)
# Downloading pyflakes-3.2.0-py2.py3-none-any.whl (62 kB)
# Downloading pyparsing-3.1.4-py3-none-any.whl (104 kB)
# Downloading tomli-2.3.0-py3-none-any.whl (14 kB)
# Downloading attrs-25.3.0-py3-none-any.whl (63 kB)
# Downloading fsspec-2025.3.0-py3-none-any.whl (193 kB)
# Downloading iniconfig-2.1.0-py3-none-any.whl (6.0 kB)
# Using cached jinja2-3.1.6-py3-none-any.whl (134 kB)
# Downloading networkx-3.1-py3-none-any.whl (2.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 2.4 MB/s eta 0:00:00a 0:00:01
# Downloading py-1.11.0-py2.py3-none-any.whl (98 kB)
# Downloading sympy-1.13.3-py3-none-any.whl (6.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.2/6.2 MB 2.0 MB/s eta 0:00:00a 0:00:01
# Downloading MarkupSafe-2.1.5-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (26 kB)
# Downloading mpmath-1.3.0-py3-none-any.whl (536 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 536.2/536.2 kB 4.8 MB/s eta 0:00:00
# Using cached nvidia_nvjitlink_cu12-12.9.86-py3-none-manylinux2010_x86_64.manylinux_2_12_x86_64.whl (39.7 MB)
# Building wheels for collected packages: chumpy
#   Building wheel for chumpy (setup.py) ... done
#   Created wheel for chumpy: filename=chumpy-0.70-py3-none-any.whl size=58279 sha256=83b28db4a543a876493073ddeb27c61ce5be5a3af32ef5d3d5046ebb159d3ed0
#   Stored in directory: /home/corentin/.cache/pip/wheels/d9/a2/b8/b8aeeeaeb01b5002085156add1aed832f2fb03e79d0f22dfed
# Successfully built chumpy
# Installing collected packages: munkres, mpmath, json_tricks, xdoctest, triton, tomli, sympy, scipy, pytest-runner, pyparsing, pyflakes, pycodestyle, py, pluggy, pillow, parameterized, opencv-python, nvidia-nvtx-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, networkx, mccabe, MarkupSafe, kiwisolver, isort, iniconfig, importlib-resources, fsspec, fonttools, exceptiongroup, cython, cycler, coverage, contourpy, attrs, yapf, pytest, nvidia-cusparse-cu12, nvidia-cudnn-cu12, matplotlib, jinja2, interrogate, flake8, chumpy, xtcocotools, nvidia-cusolver-cu12, torch, torchvision
# Successfully installed MarkupSafe-2.1.5 attrs-25.3.0 chumpy-0.70 contourpy-1.1.1 coverage-7.6.1 cycler-0.12.1 cython-3.2.3 exceptiongroup-1.3.1 flake8-7.1.2 fonttools-4.57.0 fsspec-2025.3.0 importlib-resources-6.4.5 iniconfig-2.1.0 interrogate-1.7.0 isort-4.3.21 jinja2-3.1.6 json_tricks-3.17.3 kiwisolver-1.4.7 matplotlib-3.7.5 mccabe-0.7.0 mpmath-1.3.0 munkres-1.1.4 networkx-3.1 nvidia-cublas-cu12-12.1.3.1 nvidia-cuda-cupti-cu12-12.1.105 nvidia-cuda-nvrtc-cu12-12.1.105 nvidia-cuda-runtime-cu12-12.1.105 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.0.2.54 nvidia-curand-cu12-10.3.2.106 nvidia-cusolver-cu12-11.4.5.107 nvidia-cusparse-cu12-12.1.0.106 nvidia-nccl-cu12-2.20.5 nvidia-nvjitlink-cu12-12.9.86 nvidia-nvtx-cu12-12.1.105 opencv-python-4.12.0.88 parameterized-0.9.0 pillow-10.4.0 pluggy-1.5.0 py-1.11.0 pycodestyle-2.12.1 pyflakes-3.2.0 pyparsing-3.1.4 pytest-8.3.5 pytest-runner-6.0.1 scipy-1.10.1 sympy-1.13.3 tomli-2.3.0 torch-2.4.1 torchvision-0.19.1 triton-3.0.0 xdoctest-1.3.0 xtcocotools-1.14.3 yapf-0.43.0
# Note: you may need to restart the kernel to use updated packages.
# Using pip 25.0.1 from /home/corentin/Documents/Cours/L3/Projet Midl 2/ProjetMIDL2/.env/lib/python3.8/site-packages/pip (python 3.8)
# Obtaining file:///home/corentin/Documents/Cours/L3/Projet%20Midl%202/ProjetMIDL2/mmpose
#   Preparing metadata (setup.py) ...   Running command python setup.py egg_info
#   running egg_info
#   creating /tmp/pip-pip-egg-info-17q94so6/mmpose.egg-info
#   writing manifest file '/tmp/pip-pip-egg-info-17q94so6/mmpose.egg-info/SOURCES.txt'
#   warning: no files found matching 'mmpose/.mim/model-index.yml'
#   warning: no files found matching 'mmpose/.mim/dataset-index.yml'
#   warning: no files found matching '*.py' under directory 'mmpose/.mim/configs'
#   warning: no files found matching '*.yml' under directory 'mmpose/.mim/configs'
#   warning: no files found matching '*.py' under directory 'mmpose/.mim/tools'
#   warning: no files found matching '*.sh' under directory 'mmpose/.mim/tools'
#   warning: no files found matching '*.py' under directory 'mmpose/.mim/demo'
#   writing manifest file '/tmp/pip-pip-egg-info-17q94so6/mmpose.egg-info/SOURCES.txt'
# done
# Requirement already satisfied: chumpy in ./.env/lib/python3.8/site-packages (from mmpose==1.3.2) (0.70)
# Requirement already satisfied: json_tricks in ./.env/lib/python3.8/site-packages (from mmpose==1.3.2) (3.17.3)
# Requirement already satisfied: matplotlib in ./.env/lib/python3.8/site-packages (from mmpose==1.3.2) (3.7.5)
# Requirement already satisfied: munkres in ./.env/lib/python3.8/site-packages (from mmpose==1.3.2) (1.1.4)
# Requirement already satisfied: numpy in ./.env/lib/python3.8/site-packages (from mmpose==1.3.2) (1.24.4)
# Requirement already satisfied: opencv-python in ./.env/lib/python3.8/site-packages (from mmpose==1.3.2) (4.12.0.88)
# Requirement already satisfied: pillow in ./.env/lib/python3.8/site-packages (from mmpose==1.3.2) (10.4.0)
# Requirement already satisfied: scipy in ./.env/lib/python3.8/site-packages (from mmpose==1.3.2) (1.10.1)
# Requirement already satisfied: torchvision in ./.env/lib/python3.8/site-packages (from mmpose==1.3.2) (0.19.1)
# Requirement already satisfied: xtcocotools>=1.12 in ./.env/lib/python3.8/site-packages (from mmpose==1.3.2) (1.14.3)
# Requirement already satisfied: setuptools>=18.0 in ./.env/lib/python3.8/site-packages (from xtcocotools>=1.12->mmpose==1.3.2) (60.2.0)
# Requirement already satisfied: cython>=0.27.3 in ./.env/lib/python3.8/site-packages (from xtcocotools>=1.12->mmpose==1.3.2) (3.2.3)
# Requirement already satisfied: contourpy>=1.0.1 in ./.env/lib/python3.8/site-packages (from matplotlib->mmpose==1.3.2) (1.1.1)
# Requirement already satisfied: cycler>=0.10 in ./.env/lib/python3.8/site-packages (from matplotlib->mmpose==1.3.2) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in ./.env/lib/python3.8/site-packages (from matplotlib->mmpose==1.3.2) (4.57.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in ./.env/lib/python3.8/site-packages (from matplotlib->mmpose==1.3.2) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in ./.env/lib/python3.8/site-packages (from matplotlib->mmpose==1.3.2) (24.2)
# Requirement already satisfied: pyparsing>=2.3.1 in ./.env/lib/python3.8/site-packages (from matplotlib->mmpose==1.3.2) (3.1.4)
# Requirement already satisfied: python-dateutil>=2.7 in ./.env/lib/python3.8/site-packages (from matplotlib->mmpose==1.3.2) (2.9.0.post0)
# Requirement already satisfied: importlib-resources>=3.2.0 in ./.env/lib/python3.8/site-packages (from matplotlib->mmpose==1.3.2) (6.4.5)
# Requirement already satisfied: six>=1.11.0 in ./.env/lib/python3.8/site-packages (from chumpy->mmpose==1.3.2) (1.17.0)
# Requirement already satisfied: torch==2.4.1 in ./.env/lib/python3.8/site-packages (from torchvision->mmpose==1.3.2) (2.4.1)
# Requirement already satisfied: filelock in ./.env/lib/python3.8/site-packages (from torch==2.4.1->torchvision->mmpose==1.3.2) (3.14.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in ./.env/lib/python3.8/site-packages (from torch==2.4.1->torchvision->mmpose==1.3.2) (4.13.2)
# Requirement already satisfied: sympy in ./.env/lib/python3.8/site-packages (from torch==2.4.1->torchvision->mmpose==1.3.2) (1.13.3)
# Requirement already satisfied: networkx in ./.env/lib/python3.8/site-packages (from torch==2.4.1->torchvision->mmpose==1.3.2) (3.1)
# Requirement already satisfied: jinja2 in ./.env/lib/python3.8/site-packages (from torch==2.4.1->torchvision->mmpose==1.3.2) (3.1.6)
# Requirement already satisfied: fsspec in ./.env/lib/python3.8/site-packages (from torch==2.4.1->torchvision->mmpose==1.3.2) (2025.3.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in ./.env/lib/python3.8/site-packages (from torch==2.4.1->torchvision->mmpose==1.3.2) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in ./.env/lib/python3.8/site-packages (from torch==2.4.1->torchvision->mmpose==1.3.2) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in ./.env/lib/python3.8/site-packages (from torch==2.4.1->torchvision->mmpose==1.3.2) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in ./.env/lib/python3.8/site-packages (from torch==2.4.1->torchvision->mmpose==1.3.2) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in ./.env/lib/python3.8/site-packages (from torch==2.4.1->torchvision->mmpose==1.3.2) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in ./.env/lib/python3.8/site-packages (from torch==2.4.1->torchvision->mmpose==1.3.2) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in ./.env/lib/python3.8/site-packages (from torch==2.4.1->torchvision->mmpose==1.3.2) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in ./.env/lib/python3.8/site-packages (from torch==2.4.1->torchvision->mmpose==1.3.2) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in ./.env/lib/python3.8/site-packages (from torch==2.4.1->torchvision->mmpose==1.3.2) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.20.5 in ./.env/lib/python3.8/site-packages (from torch==2.4.1->torchvision->mmpose==1.3.2) (2.20.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in ./.env/lib/python3.8/site-packages (from torch==2.4.1->torchvision->mmpose==1.3.2) (12.1.105)
# Requirement already satisfied: triton==3.0.0 in ./.env/lib/python3.8/site-packages (from torch==2.4.1->torchvision->mmpose==1.3.2) (3.0.0)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in ./.env/lib/python3.8/site-packages (from nvidia-cusolver-cu12==11.4.5.107->torch==2.4.1->torchvision->mmpose==1.3.2) (12.9.86)
# Requirement already satisfied: zipp>=3.1.0 in ./.env/lib/python3.8/site-packages (from importlib-resources>=3.2.0->matplotlib->mmpose==1.3.2) (3.20.2)
# Requirement already satisfied: MarkupSafe>=2.0 in ./.env/lib/python3.8/site-packages (from jinja2->torch==2.4.1->torchvision->mmpose==1.3.2) (2.1.5)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in ./.env/lib/python3.8/site-packages (from sympy->torch==2.4.1->torchvision->mmpose==1.3.2) (1.3.0)
# Installing collected packages: mmpose
#   DEPRECATION: Legacy editable install of mmpose==1.3.2 from file:///home/corentin/Documents/Cours/L3/Projet%20Midl%202/ProjetMIDL2/mmpose (setup.py develop) is deprecated. pip 25.1 will enforce this behaviour change. A possible replacement is to add a pyproject.toml or enable --use-pep517, and use setuptools >= 64. If the resulting installation is not behaving as expected, try using --config-settings editable_mode=compat. Please consult the setuptools documentation for more information. Discussion can be found at https://github.com/pypa/pip/issues/11457
#   Running setup.py develop for mmpose
#     Running command python setup.py develop
#     running develop
#     /home/corentin/Documents/Cours/L3/Projet Midl 2/ProjetMIDL2/.env/lib/python3.8/site-packages/setuptools/command/easy_install.py:156: EasyInstallDeprecationWarning: easy_install command is deprecated. Use build and pip and other standards-based tools.
#       warnings.warn(
#     /home/corentin/Documents/Cours/L3/Projet Midl 2/ProjetMIDL2/.env/lib/python3.8/site-packages/setuptools/command/install.py:34: SetuptoolsDeprecationWarning: setup.py install is deprecated. Use build and pip and other standards-based tools.
#       warnings.warn(
#     running egg_info
#     creating mmpose.egg-info
#     writing manifest file 'mmpose.egg-info/SOURCES.txt'
#     writing manifest file 'mmpose.egg-info/SOURCES.txt'
#     running build_ext
# Successfully installed mmpose
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# Test de l'installation avec le test fourni dans la documentation :

# %%
from mmpose.apis import inference_topdown, init_model
from mmpose.utils import register_all_modules

register_all_modules()

config_file = 'mmpose/td-hm_hrnet-w48_8xb32-210e_coco-256x192.py'
checkpoint_file = 'mmpose/td-hm_hrnet-w48_8xb32-210e_coco-256x192-0e67c616_20220913.pth'
model = init_model(config_file, checkpoint_file, device='cuda:0')

# please prepare an image with person
results = inference_topdown(model, 'mmpose/demo.jpg')

print(results)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from mmpose.apis import inference_topdown, init_model
#       2 from mmpose.utils import register_all_modules
#       4 register_all_modules()
#
# File ~/Documents/Cours/L3/Projet Midl 2/ProjetMIDL2/mmpose/mmpose/__init__.py:2
#       1 # Copyright (c) OpenMMLab. All rights reserved.
# ----> 2 import mmcv
#       3 import mmengine
#       4 from mmengine.utils import digit_version
#
# ModuleNotFoundError: No module named 'mmcv'
